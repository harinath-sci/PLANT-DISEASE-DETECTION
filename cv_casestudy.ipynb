# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.applications.xception import preprocess_input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import splitfolders
import pandas as pd
import numpy as np
import cv2 as cv
import os

# %%
train_path = "Videos/PlantVillage/train"
test_path = "Videos/PlantVillage/test"

# %%
os.listdir("Videos/PlantVillage")
# Out:
# ['test', 'train']

# %%
for i in os.listdir(train_path) :
    for j in os.listdir(train_path + "/" + i):
        img = cv.imread(train_path + "/" + i+ "/"+j)
        img = cv.cvtColor(img,cv.COLOR_BGR2RGB)
        plt.imshow(img)
    break

# %%
img.shape
# Out:
# (256, 256, 3)

# %%
for i in os.listdir(train_path) :
    for j in os.listdir(train_path + "/" + i):
        img = cv.imread(train_path + "/" + i+ "/"+j)
#         img = cv.cvtColor(img,cv.COLOR_BGR2RGB)
        img = img.reshape((256,256,3))
        cv.imwrite(train_path + "/" + i+ "/"+j, img)
        print(img.shape)
# Out:
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# ...

# %%
for i in os.listdir(test_path) :
    for j in os.listdir(test_path + "/" + i):
        img = cv.imread(test_path + "/" + i+ "/"+j)
        img = cv.cvtColor(img,cv.COLOR_BGR2RGB)
        img = img.reshape((256,256,3))
        plt.imshow(img)
    break

# %%
for i in os.listdir(test_path) :
    for j in os.listdir(test_path + "/" + i):
        img = cv.imread(test_path + "/" + i+ "/"+j)
#         img = cv.cvtColor(img,cv.COLOR_BGR2RGB)
        img = img.reshape((256,256,3))
        cv.imwrite(test_path + "/" + i+ "/"+j, img)
        print(img.shape)
# Out:
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# ...

# %%
splitfolders.ratio(train_path, output="output", seed=1337, ratio=(.9, 0.1))
# Out:
# Copying files: 16012 files [01:13, 218.62 files/s]

# %%
train_path = "output/train"
val_path = "output/val"

# %%
c1 = 0
c2 = 0
for i in os.listdir(train_path):
    c1 = c1 + 1
    for j in os.listdir(train_path + "/" + i):
        c2 = c2+ 1
print("Training : ")
print("total classes : ",c1)
print("total images : ",c2)
# Out:
# Training :
# total classes :  22
# total images :  15233

# %%
c1 = 0
c2 = 0
for i in os.listdir(test_path):
    c1 = c1 + 1
    for j in os.listdir(test_path + "/" + i):
        c2 = c2+ 1
print("Testing : ")
print("total classes : ",c1)
print("total images : ",c2)
# Out:
# Testing :
# total classes :  10
# total images :  16012

# %%
c1 = 0
c2 = 0
for i in os.listdir(val_path):
    c1 = c1 + 1
    for j in os.listdir(val_path + "/" + i):
        c2 = c2+ 1
print("validation : ")
print("total classes : ",c1)
print("total images : ",c2)
# Out:
# validation :
# total classes :  22
# total images :  1702

# %%
model = Xception(include_top = False, weights = "imagenet", input_shape = (256, 256, 3))

# %%
for layers in  model.layers :
    layers.trainable = False

# %%
flat1 = Flatten()(model.layers[-1].output)
class1 = Dense(1024, activation='relu')(flat1)
output = Dense(10, activation='softmax')(class1)
model = Model(inputs=model.inputs, outputs=output)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 127, 127, 32  864         ['input_1[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 127, 127, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 127, 127, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 125, 125, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 125, 125, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
# ...

# %%
optimizer=Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, 
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# %%
BATCH_SIZE = 16

train_generator = ImageDataGenerator(rotation_range=90, 
                                     brightness_range=[0.1, 0.7],
                                     width_shift_range=0.5, 
                                     height_shift_range=0.5,
                                     horizontal_flip=True, 
                                     vertical_flip=True,
                                     validation_split=0.15,
                                     preprocessing_function=preprocess_input) 


test_generator = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
class_subset = sorted(os.listdir('output/train/'))[:10] 
print(class_subset)
traingen = train_generator.flow_from_directory(train_path,
                                               target_size=(256, 256),
                                               class_mode='categorical',
                                               classes=class_subset,
                                               subset='training',
                                               batch_size=BATCH_SIZE, 
                                               shuffle=True,
                                               seed=5)
validgen = train_generator.flow_from_directory(train_path,
                                               target_size=(256, 256),
                                               class_mode='categorical',
                                               classes=class_subset,
                                               subset='validation',
                                               batch_size=BATCH_SIZE,
                                               shuffle=True,
                                               seed=4)

testgen = test_generator.flow_from_directory(val_path,
                                             target_size=(256, 256),
                                             class_mode=None,
                                             classes=class_subset,
                                             batch_size=1,
                                             shuffle=False,
                                             seed=4)
# Out:
# ['Amazfit bip u', 'Colgate Plax Fresh Mint Mouthwash 500 ml', 'Dettol Hand Sanitizer, 50ml', 'Engage M1 Perfume Spray For Men', 'Fastrack Analog Black Dial Unisex-Adult Watch-38024PP25', 'Fastrack FastFit Grey Dial Analog Unisex Watch', 'Fogg Xtremo', 'Listerine Cool Mint Mouthwash Liquid 250 ml', 'Tomato_Bacterial_spot', 'Tomato_Early_blight']
# Found 2928 images belonging to 10 classes.
# Found 512 images belonging to 10 classes.
# Found 385 images belonging to 10 classes.

# %%
n_steps =  30
n_val_steps = 10
n_epochs = 10

tl_checkpoint_1 = ModelCheckpoint(filepath='model1.hdf5',
                                  save_best_only=True,
                                  monitor='val_accuracy',
                                  mode='max',
                                  verbose=2)

early_stop = EarlyStopping(monitor='loss',
                           patience=10,
                           restore_best_weights=True,
                           mode='min')


vgg_history = model.fit(traingen,
                            batch_size=BATCH_SIZE,
                            epochs=n_epochs,
                            validation_data=validgen,
                            steps_per_epoch=n_steps,
                            validation_steps=n_val_steps,
                            callbacks=[tl_checkpoint_1],verbose=1)
# Out:
# Epoch 1/10
# 30/30 [==============================] - ETA: 0s - loss: 1.8642 - accuracy: 0.5083
# Epoch 1: val_accuracy improved from -inf to 0.58750, saving model to model1.hdf5
# 30/30 [==============================] - 85s 3s/step - loss: 1.8642 - accuracy: 0.5083 - val_loss: 1.3710 - val_accuracy: 0.5875
# Epoch 2/10
# 30/30 [==============================] - ETA: 0s - loss: 1.3159 - accuracy: 0.5667
# Epoch 2: val_accuracy did not improve from 0.58750
# 30/30 [==============================] - 67s 2s/step - loss: 1.3159 - accuracy: 0.5667 - val_loss: 1.3561 - val_accuracy: 0.5500
# Epoch 3/10
# 30/30 [==============================] - ETA: 0s - loss: 1.4017 - accuracy: 0.5167
# Epoch 3: val_accuracy did not improve from 0.58750
# 30/30 [==============================] - 58s 2s/step - loss: 1.4017 - accuracy: 0.5167 - val_loss: 1.3197 - val_accuracy: 0.5750
# Epoch 4/10
# 30/30 [==============================] - ETA: 0s - loss: 1.2981 - accuracy: 0.5708
# ...

# %%
plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(vgg_history.history['accuracy'])
plt.plot(vgg_history.history['val_accuracy'])
plt.legend(['Train_accuracy','val_accuracy'],loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(vgg_history.history['loss'])
plt.plot(vgg_history.history['val_loss'])
plt.legend(['Train_loss','val_loss'],loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
from keras.applications.vgg16 import VGG16

# %%
model1=VGG16(include_top = False, weights = "imagenet", input_shape = (256, 256, 3))

# %%
for layers in  model1.layers :
    layers.trainable = False

# %%
flat1 = Flatten()(model1.layers[-1].output)
class1 = Dense(1024, activation='relu')(flat1)
output = Dense(10, activation='softmax')(class1)
model1 = Model(inputs=model1.inputs, outputs=output)

# %%
model1.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
# ...

# %%
optimizer=Adam(learning_rate=0.001)
model1.compile(optimizer=optimizer, 
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# %%
n_steps =  30
n_val_steps = 10
n_epochs = 10

tl_checkpoint_1 = ModelCheckpoint(filepath='model2.hdf5',
                                  save_best_only=True,
                                  monitor='val_accuracy',
                                  mode='max',
                                  verbose=2)

early_stop = EarlyStopping(monitor='loss',
                           patience=10,
                           restore_best_weights=True,
                           mode='min')


vgg_history_1 = model1.fit(traingen,
                            batch_size=BATCH_SIZE,
                            epochs=n_epochs,
                            validation_data=validgen,
                            steps_per_epoch=n_steps,
                            validation_steps=n_val_steps,
                            callbacks=[tl_checkpoint_1],verbose=1)
# Out:
# Epoch 1/10
# 30/30 [==============================] - ETA: 0s - loss: 5.6041 - accuracy: 0.4708
# Epoch 1: val_accuracy improved from -inf to 0.62500, saving model to model2.hdf5
# 30/30 [==============================] - 94s 3s/step - loss: 5.6041 - accuracy: 0.4708 - val_loss: 2.2883 - val_accuracy: 0.6250
# Epoch 2/10
# 30/30 [==============================] - ETA: 0s - loss: 1.6781 - accuracy: 0.5688
# Epoch 2: val_accuracy did not improve from 0.62500
# 30/30 [==============================] - 102s 3s/step - loss: 1.6781 - accuracy: 0.5688 - val_loss: 1.4794 - val_accuracy: 0.5562
# Epoch 3/10
# 30/30 [==============================] - ETA: 0s - loss: 1.5683 - accuracy: 0.6229
# Epoch 3: val_accuracy did not improve from 0.62500
# 30/30 [==============================] - 108s 4s/step - loss: 1.5683 - accuracy: 0.6229 - val_loss: 1.1474 - val_accuracy: 0.5500
# Epoch 4/10
# 30/30 [==============================] - ETA: 0s - loss: 0.8697 - accuracy: 0.6812
# ...

# %%
plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(vgg_history_1.history['accuracy'])
plt.plot(vgg_history_1.history['val_accuracy'])
plt.legend(['Train_accuracy','val_accuracy'],loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(vgg_history_1.history['loss'])
plt.plot(vgg_history_1.history['val_loss'])
plt.legend(['Train_loss','val_loss'],loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
from tensorflow.keras.applications.resnet50 import ResNet50

# %%
model2=ResNet50(include_top = False, weights = "imagenet", input_shape = (256, 256, 3))
# Out:
# ...
# 94781440/94765736 [==============================] - 194s 2us/step

# %%
for layers in  model2.layers :
    layers.trainable = False

# %%
flat1 = Flatten()(model2.layers[-1].output)
class1 = Dense(1024, activation='relu')(flat1)
output = Dense(10, activation='softmax')(class1)
model2 = Model(inputs=model2.inputs, outputs=output)

# %%
model2.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_3 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 262, 262, 3)  0           ['input_3[0][0]']
#
#  conv1_conv (Conv2D)            (None, 128, 128, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 128, 128, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 128, 128, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 130, 130, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 64, 64, 64)   0           ['pool1_pad[0][0]']
#
# ...

# %%
optimizer=Adam(learning_rate=0.001)
model2.compile(optimizer=optimizer, 
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# %%
n_steps =  30
n_val_steps = 10
n_epochs = 10

tl_checkpoint_1 = ModelCheckpoint(filepath='model2.hdf5',
                                  save_best_only=True,
                                  monitor='val_accuracy',
                                  mode='max',
                                  verbose=2)

early_stop = EarlyStopping(monitor='loss',
                           patience=10,
                           restore_best_weights=True,
                           mode='min')


vgg_history_2 = model2.fit(traingen,
                            batch_size=BATCH_SIZE,
                            epochs=n_epochs,
                            validation_data=validgen,
                            steps_per_epoch=n_steps,
                            validation_steps=n_val_steps,
                            callbacks=[tl_checkpoint_1],verbose=1)
# Out:
# Epoch 1/10
# 30/30 [==============================] - ETA: 0s - loss: 22.2537 - accuracy: 0.3792
# Epoch 1: val_accuracy improved from -inf to 0.37500, saving model to model2.hdf5
# 30/30 [==============================] - 63s 2s/step - loss: 22.2537 - accuracy: 0.3792 - val_loss: 9.9691 - val_accuracy: 0.3750
# Epoch 2/10
# 30/30 [==============================] - ETA: 0s - loss: 7.8152 - accuracy: 0.4500
# Epoch 2: val_accuracy did not improve from 0.37500
# 30/30 [==============================] - 61s 2s/step - loss: 7.8152 - accuracy: 0.4500 - val_loss: 6.4964 - val_accuracy: 0.0125
# Epoch 3/10
# 30/30 [==============================] - ETA: 0s - loss: 4.1467 - accuracy: 0.4729
# Epoch 3: val_accuracy improved from 0.37500 to 0.55000, saving model to model2.hdf5
# 30/30 [==============================] - 68s 2s/step - loss: 4.1467 - accuracy: 0.4729 - val_loss: 2.3035 - val_accuracy: 0.5500
# Epoch 4/10
# ...

# %%
plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(vgg_history_2.history['accuracy'])
plt.plot(vgg_history_2.history['val_accuracy'])
plt.legend(['Train_accuracy','val_accuracy'],loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(vgg_history_2.history['loss'])
plt.plot(vgg_history_2.history['val_loss'])
plt.legend(['Train_loss','val_loss'],loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
from keras import layers
from keras import models

model3 = models.Sequential()

model3.add(layers.Conv2D(32, (3, 3), activation='relu',
                        input_shape=(256, 256, 3)))
model3.add(layers.MaxPooling2D((2, 2)))

model3.add(layers.Conv2D(64, (3, 3), activation='relu'))
model3.add(layers.MaxPooling2D((2, 2)))

model3.add(layers.Conv2D(128, (3, 3), activation='relu'))
model3.add(layers.MaxPooling2D((2, 2)))

model3.add(layers.Conv2D(128, (3, 3), activation='relu'))
model3.add(layers.MaxPooling2D((2, 2)))

model3.add(layers.Flatten())
model3.add(layers.Dense(512, activation='relu'))
model3.add(layers.Dense(10, activation='softmax'))

# %%
model3.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_4 (Conv2D)           (None, 254, 254, 32)      896
#
#  max_pooling2d_4 (MaxPooling  (None, 127, 127, 32)     0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 125, 125, 64)      18496
#
#  max_pooling2d_5 (MaxPooling  (None, 62, 62, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 60, 60, 128)       73856
#
#  max_pooling2d_6 (MaxPooling  (None, 30, 30, 128)      0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 128)       147584
#
#  max_pooling2d_7 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_2 (Dense)             (None, 512)               12845568
#
#  dense_3 (Dense)             (None, 10)                5130
#
# ...
# Total params: 13,091,530
# Trainable params: 13,091,530
# Non-trainable params: 0
# ...

# %%
optimizer=Adam(learning_rate=0.001)
model3.compile(optimizer=optimizer, 
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# %%
n_steps =  30
n_val_steps = 10
n_epochs = 10

tl_checkpoint_1 = ModelCheckpoint(filepath='model3.hdf5',
                                  save_best_only=True,
                                  monitor='val_accuracy',
                                  mode='max',
                                  verbose=2)

early_stop = EarlyStopping(monitor='loss',
                           patience=10,
                           restore_best_weights=True,
                           mode='min')


vgg_history_3 = model3.fit(traingen,
                            batch_size=BATCH_SIZE,
                            epochs=n_epochs,
                            validation_data=validgen,
                            steps_per_epoch=n_steps,
                            validation_steps=n_val_steps,
                            callbacks=[tl_checkpoint_1],verbose=1)
# Out:
# Epoch 1/10
# 30/30 [==============================] - ETA: 0s - loss: 1.4716 - accuracy: 0.5000
# Epoch 1: val_accuracy improved from -inf to 0.58750, saving model to model3.hdf5
# 30/30 [==============================] - 71s 2s/step - loss: 1.4716 - accuracy: 0.5000 - val_loss: 1.2619 - val_accuracy: 0.5875
# Epoch 2/10
# 30/30 [==============================] - ETA: 0s - loss: 1.3232 - accuracy: 0.5375
# Epoch 2: val_accuracy did not improve from 0.58750
# 30/30 [==============================] - 65s 2s/step - loss: 1.3232 - accuracy: 0.5375 - val_loss: 1.2387 - val_accuracy: 0.5500
# Epoch 3/10
# 30/30 [==============================] - ETA: 0s - loss: 1.2730 - accuracy: 0.5417
# Epoch 3: val_accuracy improved from 0.58750 to 0.60625, saving model to model3.hdf5
# 30/30 [==============================] - 65s 2s/step - loss: 1.2730 - accuracy: 0.5417 - val_loss: 1.0706 - val_accuracy: 0.6062
# Epoch 4/10
# ...

# %%
plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(vgg_history_3.history['accuracy'])
plt.plot(vgg_history_3.history['val_accuracy'])
plt.legend(['Train_accuracy','val_accuracy'],loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(vgg_history_3.history['loss'])
plt.plot(vgg_history_3.history['val_loss'])
plt.legend(['Train_loss','val_loss'],loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
